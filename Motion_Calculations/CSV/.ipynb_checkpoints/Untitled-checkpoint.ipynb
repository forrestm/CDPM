# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
resp = np.genfromtxt('response_0.csv', delimiter=',')
shaped = np.genfromtxt('response_s_0.csv', delimiter=',')
t = np.genfromtxt('sim_time.csv', delimiter=',')

# %%
plt.plot(t, np.degrees(shaped[:,2]))
plt.plot(t, np.degrees(resp[:,2]))

# %%
a = np.where(shaped >= 11.6825)[0]

# %%
np.max(shaped)
# Out:
# 10.001348923086772
