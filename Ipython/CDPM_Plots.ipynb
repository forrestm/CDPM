# %%
# import the plotting functions from matplotlib
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
# Out:
# //anaconda/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# //anaconda/lib/python3.5/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
# from matplotlib import rc
# import matplotlib.pylab as plt

# rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
# rc('text', usetex=True)
# %matplotlib inline

# %%
# import matplotlib
# import matplotlib.font_manager as font_manager

# fontpath = '/Users/forrest/Library/Fonts/cmunbx.otf'

# prop = font_manager.FontProperties(fname=fontpath)
# matplotlib.rcParams['font.family'] = prop.get_name()

# %%
# from matplotlib import font_manager 
# font_manager.findfont('CMU Serif Bold')

# %%
# from matplotlib import rc
# rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
# ## for Palatino and other serif fonts use:
# #rc('font',**{'family':'serif','serif':['Palatino']})
# rc('text', usetex=True)

# %%
# plt.rc('text', usetex=False) 
# plt.rc('font', family='serif')

# %%
import numpy as np
# X_Y = np.genfromtxt('dims_10000.csv', delimiter=',')
# High_mode = np.genfromtxt('nat_freq_high_eigen_no_zero.csv', delimiter=',')
# Med_mode = np.genfromtxt('nat_freq_medium_eigen_no_zero.csv', delimiter=',')
# Low_mode = np.genfromtxt('nat_freq_low_eigen_no_zero.csv', delimiter=',')
# damping = np.genfromtxt('damping_no_zero.csv', delimiter=',')
response = np.genfromtxt('response.csv', delimiter=',')
response_shaped = np.genfromtxt('response_s.csv', delimiter=',')
sim_time = np.genfromtxt('sim_time.csv', delimiter=',')
# n = 10000

# %%
R_amount_shaped = np.sqrt(((response_shaped[:,0] + 3 * np.sin(response_shaped[:,2])) - 10)**2 +
           ((response_shaped[:,1] + 3 * np.cos(response_shaped[:,2])) - 7.5)**2)

R_amount_unshaped = np.sqrt(((response[:,0] + 3 * np.sin(response[:,2])) - 10)**2 +
           ((response[:,1] + 3 * np.cos(response[:,2])) - 7.5)**2)

# %%
# Set the plot size - 3x2 aspect ratio is best
fig = plt.figure(figsize=(6, 4))
ax = plt.gca()
plt.subplots_adjust(bottom=0.17, left=0.17, top=0.96, right=0.96)

# csfont = {'fontname':'CMU Serif'}
# Change the axis units to serif
plt.setp(ax.get_ymajorticklabels(), fontsize=18)
plt.setp(ax.get_xmajorticklabels(), fontsize=18)

# Remove top and right axes border
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Only show axes ticks on the bottom and left axes
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Turn on the plot grid and set appropriate linestyle and color
ax.grid(True,linestyle=':', color='0.75')
ax.set_axisbelow(True)

# Define the X and Y axis labels
plt.xlabel(r'Time (s)', fontsize=22, labelpad=5)
plt.ylabel(r'Displacement (m)', fontsize=22, labelpad=10)

# Plot the data

plt.plot(sim_time, R_amount_unshaped, linewidth=2, linestyle='--', label = r'Unshaped')
plt.plot(sim_time, R_amount_shaped, linewidth=2, linestyle='-', label = r'Shaped')
# uncomment below and set limits if needed
# plt.xlim(0, 5)
# plt.ylim(9, 16.5)

# Create the legend, then fix the fontsize
leg = plt.legend(loc='best', ncol = 1, fancybox=True)
ltext  = leg.get_texts()
plt.setp(ltext, fontsize=20)

# Adjust the page layout filling the page using the new tight_layout command
plt.tight_layout(pad=0.5)

# Uncomment to save the figure as a high-res pdf in the current folder
# It's saved at the original 6x4 size
plt.savefig('motion_unshaped.pdf')

fig.set_size_inches(9, 6) # Resize the figure for better display in the notebook

# %%
# Set the plot size - 3x2 aspect ratio is best
fig = plt.figure(figsize=(6, 4))
ax = plt.gca()
plt.subplots_adjust(bottom=0.17, left=0.17, top=0.96, right=0.96)

# Change the axis units to serif
plt.setp(ax.get_ymajorticklabels(), family='serif', fontsize=18)
plt.setp(ax.get_xmajorticklabels(), family='serif', fontsize=18)

# Remove top and right axes border
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Only show axes ticks on the bottom and left axes
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Turn on the plot grid and set appropriate linestyle and color
ax.grid(True,linestyle=':', color='0.75')
ax.set_axisbelow(True)

# Define the X and Y axis labels
plt.xlabel('Time (s)', family='cmr10', fontsize=22, labelpad=5)
plt.ylabel('Displacement (m)', family='cmr10', fontsize=22, labelpad=10)

# Plot the data
plt.plot(sim_time, response[:, 1], linewidth=2, linestyle='--', label = r'Unshaped')
plt.plot(sim_time, response_shaped[:, 1], linewidth=2, linestyle='-', label = r'Shaped')

# uncomment below and set limits if needed
# plt.xlim(0, 5)
plt.ylim(6.5, 13.5)

# Create the legend, then fix the fontsize
leg = plt.legend(loc='best', ncol = 1, fancybox=True)
ltext  = leg.get_texts()
plt.setp(ltext, family='cmr10', fontsize=20)

# Adjust the page layout filling the page using the new tight_layout command
plt.tight_layout(pad=0.5)

# Uncomment to save the figure as a high-res pdf in the current folder
# It's saved at the original 6x4 size
# plt.savefig('Y_motion_shaped.pdf')

fig.set_size_inches(9, 6) # Resize the figure for better display in the notebook

# %%
# Set the plot size - 3x2 aspect ratio is best
fig = plt.figure(figsize=(6, 4))
ax = plt.gca()
plt.subplots_adjust(bottom=0.17, left=0.17, top=0.96, right=0.96)

# Change the axis units to serif
plt.setp(ax.get_ymajorticklabels(), family='serif', fontsize=18)
plt.setp(ax.get_xmajorticklabels(), family='serif', fontsize=18)

# Remove top and right axes border
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Only show axes ticks on the bottom and left axes
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Turn on the plot grid and set appropriate linestyle and color
ax.grid(True,linestyle=':', color='0.75')
ax.set_axisbelow(True)

# Define the X and Y axis labels
plt.xlabel(r'\textbf{Time (s)}', family='serif', fontsize=22, weight='bold', labelpad=5)
plt.ylabel(r'\textbf{Angle (Degrees)}', family='serif', fontsize=22, weight='bold', labelpad=10)

# Plot the data
plt.plot(sim_time, np.degrees(response[:, 2]), linewidth=2, linestyle='--', label = r'Unshaped', color='b')
plt.plot(sim_time, np.degrees(response_shaped[:, 2]), linewidth=2, linestyle='-', label = r'Shaped', color='g')

# uncomment below and set limits if needed
# plt.xlim(0, 5)
# plt.ylim(-1, 5)

# Create the legend, then fix the fontsize
leg = plt.legend(loc='lower right', ncol = 1, fancybox=True)
ltext  = leg.get_texts()
plt.setp(ltext, family='serif', fontsize=20)

# Adjust the page layout filling the page using the new tight_layout command
plt.tight_layout(pad=0.5)

# Uncomment to save the figure as a high-res pdf in the current folder
# It's saved at the original 6x4 size
plt.savefig('Beta_motion_shaped.pdf')

fig.set_size_inches(9, 6) # Resize the figure for better display in the notebook

# %%
# Set the plot size - 3x2 aspect ratio is best
fig = plt.figure(figsize=(6, 4))
ax = plt.gca()
plt.subplots_adjust(bottom=0.17, left=0.17, top=0.96, right=0.96)

# Change the axis units to serif
plt.setp(ax.get_ymajorticklabels(), family='serif', fontsize=18)
plt.setp(ax.get_xmajorticklabels(), family='serif', fontsize=18)

# Remove top and right axes border
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Only show axes ticks on the bottom and left axes
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Turn on the plot grid and set appropriate linestyle and color
ax.grid(True,linestyle=':', color='0.75')
ax.set_axisbelow(True)

# Define the X and Y axis labels
plt.xlabel('X Position (m)', family='serif', fontsize=22, weight='bold', labelpad=5)
plt.ylabel('Y Position (m)', family='serif', fontsize=22, weight='bold', labelpad=10)

# Plot the data
# plt.plot(sim_time, response[:, 1], linewidth=2, linestyle='--', label = r'Unshaped')
# plt.plot(sim_time, response_shaped[:, 1], linewidth=2, linestyle='-', label = r'Shaped')

plt.plot(response[:,0], response[:,1], linewidth=2)
plt.plot(response[:,0] + 0.5/2 * np.sin(response[:,2]) , response[:,1] + 0.5/2 * np.cos(response[:,2]), linewidth=2)
plt.plot(response[:,0] + 1/2 * np.sin(response[:,2]) , response[:,1] + 1/2 * np.cos(response[:,2]), linewidth=2)

# plt.plot(response_shaped[:,0], response_shaped[:,1])
# plt.plot(response_shaped[:,0] + 0.5/2 * np.sin(response_shaped[:,2]) , response_shaped[:,1] + 0.5/2 * np.cos(response_shaped[:,2]), label =r'Shaped', linewidth=2)
# plt.plot(response_shaped[:,0] + 1/2 * np.sin(response_shaped[:,2]) , response_shaped[:,1] + 1/2 * np.cos(response_shaped[:,2]), label =r'Shaped', linewidth=2)

# uncomment below and set limits if needed
plt.ylim(14,6)
plt.xlim(8,18)

# Create the legend, then fix the fontsize
# leg = plt.legend(loc='best', ncol = 2, fancybox=True)
# ltext  = leg.get_texts()
plt.setp(ltext, family='serif', fontsize=20)

# Adjust the page layout filling the page using the new tight_layout command
plt.tight_layout(pad=0.5)

# Uncomment to save the figure as a high-res pdf in the current folder
# It's saved at the original 6x4 size
plt.savefig('Total_motion.pdf')

fig.set_size_inches(9, 6) # Resize the figure for better display in the notebook

# %%
import seaborn as sns
sns.set(context="paper", font_scale=2)
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
plt.figure(0)
fig = plt.figure(figsize=(6, 4))
Heat1 = np.hstack((np.fliplr(X_Y), np.reshape(Low_mode,(n,1))))
df = pd.DataFrame(Heat1, columns=list('YXF'))
Heats1 = df.pivot("Y", "X", "F")
# Draw a heatmap with the numeric values in each cell
ax1 = sns.heatmap(Heats1, annot=False, fmt="d", linewidths=0, cmap="inferno", xticklabels=False, 
            yticklabels=False, cbar=False)
cbar = ax1.figure.colorbar(ax1.collections[0])
cbar.ax.set_title('Hz')
# plt.title('Low Mode Natural Frequency Across Workspace', y = 1.05)
plt.xlabel('X Position (m)')
plt.ylabel('Y Position (m)')
# plt.savefig("Low_Mode_Natural_Frequency.pdf")

plt.figure(1)
fig = plt.figure(figsize=(6, 4))
Heat1 = np.hstack((np.fliplr(X_Y), np.reshape(Med_mode,(n,1))))
df = pd.DataFrame(Heat1, columns=list('YXF'))
Heats1 = df.pivot("Y", "X", "F")
# Draw a heatmap with the numeric values in each cell
ax2 = sns.heatmap(Heats1, annot=False, fmt="d", linewidths=0, cmap="inferno", xticklabels=False, 
            yticklabels=False, cbar=False)
cbar = ax2.figure.colorbar(ax2.collections[0])
cbar.ax.set_title('Hz')
# plt.title('Medium Mode Natural Frequency Across Workspace', y = 1.05)
plt.xlabel('X Position (m)')
plt.ylabel('Y Position (m)')
# plt.savefig("Medium_Mode_Natural_Frequency.pdf")

plt.figure(2)
fig = plt.figure(figsize=(6, 4))
Heat1 = np.hstack((np.fliplr(X_Y), np.reshape(High_mode,(n,1))))
df = pd.DataFrame(Heat1, columns=list('YXF'))
Heats1 = df.pivot("Y", "X", "F")
# Draw a heatmap with the numeric values in each cell
ax3 = sns.heatmap(Heats1, annot=False, fmt="d", linewidths=0, cmap="inferno", xticklabels=False, 
            yticklabels=False, cbar=False)
cbar = ax3.figure.colorbar(ax3.collections[0])
cbar.ax.set_title('Hz')
# plt.title('High Mode Natural Frequency Across Workspace', y = 1.05)
plt.xlabel('X Position (m)')
plt.ylabel('Y Position (m)')
# plt.savefig("High_Mode_Natural_Frequency.pdf")

# plt.figure(3)
# Heat1 = np.hstack((np.fliplr(X_Y), np.reshape(damping,(n,1))))
# df = pd.DataFrame(Heat1, columns=list('YXF'))
# Heats1 = df.pivot("Y", "X", "F")
# # Draw a heatmap with the numeric values in each cell
# sns.heatmap(Heats1, annot=False, fmt="d", linewidths=0, cmap="YlGnBu", xticklabels=False, 
#             yticklabels=False)
# # plt.title('Damping Across Workspace', y = 1.05)
# plt.savefig("Damping.pdf")

# %%
# np.average(Low_mode)
np.nanmean(damping)

# %%
np.average(High_mode)

# %%
def s_curve(CurrTime, Begin, Amp, RiseTime, StartTime):
    """
    This was copied from Dr. Vaughan's Input shaping Library
    I edited it to allow for a beginning value.

    Function to generate an s-curve command

    Arguments:
      CurrTime : The current timestep or an array of times
      Amp : The magnitude of the s-curve (or final setpoint)
      RiseTime : The rise time of the curve
      StartTime : The time that the command should StartTime
      Begin : The beginning value

    Returns :
      The command at the current timestep or an array representing the command
      over the times given (if CurrTime was an array)
    """

    Amp = Amp - Begin

    scurve = 2.0 * ((CurrTime - StartTime)/RiseTime)**2 * (CurrTime-StartTime >=
             0) * (CurrTime-StartTime < RiseTime/2) + (-2.0 * ((CurrTime -
             StartTime)/RiseTime)**2 + 4.0 * ((CurrTime - StartTime) /RiseTime)
             - 1.0) * (CurrTime-StartTime >= RiseTime/2) * (CurrTime-StartTime <
             RiseTime) + 1.0 * (CurrTime-StartTime >= RiseTime)

    return (Amp * scurve) + Begin

# %%
t = np.linspace(0.0, 10, 1000)
plt.plot(t, s_curve(t, 15.62, 20.61, 3.0, 1.0))

# %%
s_curve(t, 15.62, 20.61, 3.0, 1.0)
# Out:
# array([ 15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
#         15.62      ,  15.62      ,  15.62      ,  15.62      ,
# ...
