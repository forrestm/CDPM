# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
# %matplotlib inline
Unshaped = np.array([0,0,0,0,0,0])

# %%
# list_of_files = glob.glob('/Users/forrest/Desktop/Supervisory Controller/*.csv')
# latest_file = max(list_of_files, key=os.path.getctime)
# filename =  latest_file
# filename = '/Users/forrest/Desktop/Unshaped/1-5s/CDPM_Data_2017-05-10_1.csv'
# filename = '/Users/forrest/Desktop/Unshaped/1-5s/CDPM_Data_2017-05-10_2.csv'
# filename = '/Users/forrest/Desktop/Unshaped/1-5s/CDPM_Data_2017-05-10_3.csv'
# filename = '/Users/forrest/Desktop/Unshaped/1-5s/CDPM_Data_2017-05-10_4.csv'
# filename = '/Users/forrest/Desktop/Unshaped/1-5s/CDPM_Data_2017-05-10_5.csv'
# filename = '/Users/forrest/Desktop/Unshaped/1-5s/CDPM_Data_2017-05-10_6.csv'

# filename = '/Users/forrest/Desktop/Unshaped/2-5s/CDPM_Data_2017-05-10_1.csv'
# filename = '/Users/forrest/Desktop/Unshaped/2-5s/CDPM_Data_2017-05-10_2.csv'
# filename = '/Users/forrest/Desktop/Unshaped/2-5s/CDPM_Data_2017-05-10_3.csv'
# filename = '/Users/forrest/Desktop/Unshaped/2-5s/CDPM_Data_2017-05-10_4.csv'
# filename = '/Users/forrest/Desktop/Unshaped/2-5s/CDPM_Data_2017-05-10_5.csv'
# filename = '/Users/forrest/Desktop/Unshaped/2-5s/CDPM_Data_2017-05-10_6.csv'

filename = '/Users/forrest/Desktop/Thesis_Temp/Unshaped/3-5s/CDPM_Data_2017-05-10_3-5_1.csv'
# filename = '/Users/forrest/Desktop/Thesis_Temp/Unshaped/3-5s/CDPM_Data_2017-05-10_3-5_2.csv'
# filename = '/Users/forrest/Desktop/Thesis_Temp/Unshaped/3-5s/CDPM_Data_2017-05-10_3-5_3.csv'
# filename = '/Users/forrest/Desktop/Thesis_Temp/Unshaped/3-5s/CDPM_Data_2017-05-10_3-5_4.csv'
# filename = '/Users/forrest/Desktop/Thesis_Temp/Unshaped/3-5s/CDPM_Data_2017-05-10_3-5_5.csv'
# filename = '/Users/forrest/Desktop/Thesis_Temp/Unshaped/3-5s/CDPM_Data_2017-05-10_3-5_6.csv'
# filename = '/Users/forrest/Desktop/Thesis_Temp/Unshaped/3-5s/CDPM_Data_2017-05-10_3-5_6.csv'
# ---------------
# filename = '/Users/forrest/Desktop/Shaped/EI/1-5s/CDPM_Data_2017-05-10_1-5_1.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/1-5s/CDPM_Data_2017-05-10_1-5_2.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/1-5s/CDPM_Data_2017-05-10_1-5_3.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/1-5s/CDPM_Data_2017-05-10_1-5_4.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/1-5s/CDPM_Data_2017-05-10_1-5_5.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/1-5s/CDPM_Data_2017-05-10_1-5_6.csv'

# filename = '/Users/forrest/Desktop/Shaped/EI/2-5s/CDPM_Data_2017-05-10_2-5_1.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/2-5s/CDPM_Data_2017-05-10_2-5_2.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/2-5s/CDPM_Data_2017-05-10_2-5_3.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/2-5s/CDPM_Data_2017-05-10_2-5_4.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/2-5s/CDPM_Data_2017-05-10_2-5_5.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/2-5s/CDPM_Data_2017-05-10_2-5_6.csv'

# filename = '/Users/forrest/Desktop/Shaped/EI/3-5s/CDPM_Data_2017-05-10_3-5_1.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/3-5s/CDPM_Data_2017-05-10_3-5_2.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/3-5s/CDPM_Data_2017-05-10_3-5_3.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/3-5s/CDPM_Data_2017-05-10_3-5_4.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/3-5s/CDPM_Data_2017-05-10_3-5_5.csv'
# filename = '/Users/forrest/Desktop/Shaped/EI/3-5s/CDPM_Data_2017-05-10_3-5_6.csv'
# ---------------
# filename = '/Users/forrest/Desktop/Shaped/ZV/1-5s/CDPM_Data_2017-05-10_1-5_1.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/1-5s/CDPM_Data_2017-05-10_1-5_2.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/1-5s/CDPM_Data_2017-05-10_1-5_3.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/1-5s/CDPM_Data_2017-05-10_1-5_4.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/1-5s/CDPM_Data_2017-05-10_1-5_5.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/1-5s/CDPM_Data_2017-05-10_1-5_6.csv'

# filename = '/Users/forrest/Desktop/Shaped/ZV/2-5s/CDPM_Data_2017-05-10_2-5_1.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/2-5s/CDPM_Data_2017-05-10_2-5_2.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/2-5s/CDPM_Data_2017-05-10_2-5_3.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/2-5s/CDPM_Data_2017-05-10_2-5_4.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/2-5s/CDPM_Data_2017-05-10_2-5_5.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/2-5s/CDPM_Data_2017-05-10_2-5_6.csv'

# filename = '/Users/forrest/Desktop/Shaped/ZV/3-5s/CDPM_Data_2017-05-10_3-5_1.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/3-5s/CDPM_Data_2017-05-10_3-5_2.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/3-5s/CDPM_Data_2017-05-10_3-5_3.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/3-5s/CDPM_Data_2017-05-10_3-5_4.csv'
# filename = '/Users/forrest/Desktop/Shaped/ZV/3-5s/CDPM_Data_2017-05-10_3-5_5.csv'
# filename = '/Users/forrest/Desktop/Thesis_Temp/Shaped/ZV/3-5s/CDPM_Data_2017-05-10_3-5_6.csv'


time, roll, pitch, yaw, x_accel, y_accel, z_accel, box1_command, box1_angle,box1_angVel, box2_command, box2_angle, box2_angVel, L1, L1_dot, L1_command,L2, L2_dot, L2_command, theta1, theta1_dot, theta2, theta2_dot, x_pos,y_pos, xd_dot, yd_dot = np.loadtxt(filename, delimiter=',', unpack=True)

# %%
box1_stop_index = np.max(L1_command.nonzero())
box2_stop_index = np.max(L2_command.nonzero())

box1_start_index = np.min(L1_command.nonzero())
box2_start_index = np.min(L2_command.nonzero())

if box1_start_index >= box2_start_index:
    start_time = time[box1_start_index]
    start_index = box1_start_index
else:
    start_time = time[box2_stop_index]
    start_index = box2_start_index
    
if box1_stop_index >= box2_stop_index:
    stop_time = time[box1_stop_index]
    stop_index = box1_stop_index
else:
    stop_time = time[box2_stop_index]
    stop_index = box2_stop_index
command_length = stop_time - start_time
max_amp = np.max(np.abs(pitch[stop_index:]))
start_x = x_pos[0]
start_y = y_pos[0]
end_x = x_pos[-1]
end_y = y_pos[-1]
distance = np.sqrt((end_x - start_x)**2 + (end_y - start_y)**2)
average_velocity = distance / command_length
total = np.array([start_x, start_y, max_amp, start_time, stop_time, average_velocity])
Unshaped = np.vstack((Unshaped,total))
Unshaped
# Out:
# array([[   0.        ,    0.        ,    0.        ,    0.        ,
#            0.        ,    0.        ],
#        [   0.55224288,    1.02214923,  106.10001892,    1.01219392,
#            3.74211907,    0.31933903]])

# %%
ZV_shaped_3_5 = Unshaped[1:]

# %%
# Total = np.vstack((Unshaped_1_5,Unshaped_2_5,Unshaped_3_5))
# Total = np.vstack((EI_shaped_1_5,EI_shaped_2_5,EI_shaped_3_5))
Total = np.vstack((ZV_shaped_1_5,ZV_shaped_2_5,ZV_shaped_3_5))

# np.save('/Users/forrest/Desktop/Total_ZV_Shaped',Total)
# plt.scatter(Total[:,0], Total[:,1])
# plt.xlim(0,2.6)
# plt.ylim(2.6,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3be50be0a229> in <module>()
#       1 # Total = np.vstack((Unshaped_1_5,Unshaped_2_5,Unshaped_3_5))
#       2 # Total = np.vstack((EI_shaped_1_5,EI_shaped_2_5,EI_shaped_3_5))
# ----> 3 Total = np.vstack((ZV_shaped_1_5,ZV_shaped_2_5,ZV_shaped_3_5))
#       4
#       5 # np.save('/Users/forrest/Desktop/Total_ZV_Shaped',Total)
#
# NameError: name 'ZV_shaped_1_5' is not defined

# %%
Total = np.load('/Users/forrest/Desktop/Unshaped/Total_Unshaped.npy')

# %%
fig = plt.figure(figsize=(6,4))
ax = plt.gca()
plt.subplots_adjust(bottom=0.17, left=0.17, top=0.96, right=0.96)

# Change the axis units font
plt.setp(ax.get_ymajorticklabels(),fontsize=18)
plt.setp(ax.get_xmajorticklabels(),fontsize=18)

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Turn on the plot grid and set appropriate linestyle and color
ax.grid(True,linestyle=':', color='0.75')
ax.set_axisbelow(True)

# Define the X and Y axis labels
plt.xlabel('Time (s)', fontsize=22, weight='bold', labelpad=5)
plt.ylabel('Rate of Change (m/s)', fontsize=22, weight='bold', labelpad=10)

# plt.plot(time, roll, linewidth=2, linestyle='-', label=r'Roll')
# plt.plot(time2, pitch2, linewidth=2, linestyle='-', label=r'Shaped')
plt.plot(time2[:250], L1_command[:250], linewidth=2, linestyle='-', label=r'$L_{1}$ Command')
plt.plot(time2[:250], L1_dot[:250], linewidth=2, linestyle=':', label=r'$L_{1}$ Command')
plt.plot(time2[:250], L2_command[:250], linewidth=2, linestyle='--', label=r'$L_{2}$ Actual')
plt.plot(time2[:250], L2_dot[:250], linewidth=2, linestyle='-.', label=r'$L_{2}$ Actual')
# plt.plot(time, pitch, linewidth=2, linestyle=':', label=r'Unshaped')
# plt.plot(time, yaw, linewidth=2, linestyle='-.', label=r'Yaw')

# uncomment below and set limits if needed
plt.xlim(0,5.5)
plt.ylim(-0.2,0.7)

# Create the legend, then fix the fontsize
leg = plt.legend(loc='upper right', ncol = 2, fancybox=True)
ltext  = leg.get_texts()
plt.setp(ltext,fontsize=18)

# Adjust the page layout filling the page using the new tight_layout command
plt.tight_layout(pad=0.5)

# save the figure as a high-res pdf in the current folder
plt.savefig('/Users/forrest/Desktop/Actual_vsCommand.pdf')

# %%
fig = plt.figure(figsize=(6,4))
ax = plt.gca()
plt.subplots_adjust(bottom=0.17, left=0.17, top=0.96, right=0.96)

# Change the axis units font
plt.setp(ax.get_ymajorticklabels(),fontsize=18)
plt.setp(ax.get_xmajorticklabels(),fontsize=18)

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Turn on the plot grid and set appropriate linestyle and color
ax.grid(True,linestyle=':', color='0.75')
ax.set_axisbelow(True)

# Define the X and Y axis labels
plt.xlabel('Time (s)', fontsize=22, weight='bold', labelpad=5)
plt.ylabel('Angular Velocity (Deg/s)', fontsize=22, weight='bold', labelpad=10)

# plt.plot(time, roll, linewidth=2, linestyle='-', label=r'Roll')
# plt.plot(time[46:], pitch2[46:], linewidth=2, linestyle='-', label=r'Pitch')
plt.plot(time[:800], pitch[:800], linewidth=2, linestyle=':', label=r'Unshaped',color='#377eb8')
plt.plot(time2, pitch2, linewidth=2, linestyle='-', label=r'Shaped',color='#e41a1c')
# plt.plot(time, yaw, linewidth=2, linestyle='-.', label=r'Yaw')

# uncomment below and set limits if needed
plt.xlim(0,15)
plt.ylim(-200,300)

# Create the legend, then fix the fontsize
leg = plt.legend(loc='upper right', ncol = 1, fancybox=True)
ltext  = leg.get_texts()
plt.setp(ltext,fontsize=18)

# Adjust the page layout filling the page using the new tight_layout command
plt.tight_layout(pad=0.5)

# save the figure as a high-res pdf in the current folder
plt.savefig('/Users/forrest/Desktop/Pendulum_experimental.pdf')

# %%
# plt.scatter(x_pos, y_pos, c=time, cmap='Blues')
# plt.xlim(0,1.5)
# plt.ylim(2,1.5)
plt.plot(time, pitch)

# %%
Total_ZV = np.load('/Users/forrest/Desktop/Shaped/ZV/Total_ZV_Shaped.npy')
Total_EI = np.load('/Users/forrest/Desktop/Shaped/EI/Total_EI_Shaped.npy')
Total_Un = np.load('/Users/forrest/Desktop/Unshaped/Total_Unshaped.npy')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = plt.axes()
# ax = fig.add_subplot(111, projection='3d')
residual_zv = (Total_ZV[:,2]/Total_Un[:,2])*100
residual_ei = (Total_EI[:,2]/Total_Un[:,2])*100
plt.scatter(Total_ZV[:,0],Total_ZV[:,1], c=residual_ei, s=70,cmap=plt.cm.Reds)
# plt.scatter(Total_ZV[:,0],Total_ZV[:,1], c=Total_ZV[:,2], s=70,cmap=plt.cm.bwr)
# plt.scatter(Total_EI[:,0],Total_EI[:,1], c=Total_EI[:,2], s=70,cmap=plt.cm.Reds,marker='v')
# ax.scatter3D(Total_Un[:,0], Total_Un[:,1], zs=residual_zv,c=residual_zv, s=70,cmap=plt.cm.bwr)
cbar = plt.colorbar()
cbar.ax.set_title('Percent\n Residual Vibration')
plt.xlim(0.5,1.3)
plt.ylim(2.25,0.4)
plt.xlabel('Horizontal Displacement')
plt.ylabel('Vertical Displacement')
# ax.annotate('Zone 1', xy=(0.17, 0.33), xytext=(0.17, 0.2), xycoords='axes fraction', 
#             fontsize=10*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white',edgecolor='none'),
#             arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0.3', lw=2.0))
ax.text(0.6, 2, 'Zone 1', color='black', size=15,
        bbox=dict(facecolor='none', edgecolor='none'))
ax.text(0.84, 2, 'Zone 2', color='black', size=15,
        bbox=dict(facecolor='none', edgecolor='none'))
ax.text(1.12, 2, 'Zone 3', color='black', size=15,
        bbox=dict(facecolor='none', edgecolor='none'))
plt.savefig('/Users/forrest/Desktop/EI_experimental')

# %%
delta = (Total_ZV[:,3] + Total_ZV[:,4]) - (Total_Un[:,3] + Total_Un[:,4])
deltaei = (Total_EI[:,3] + Total_EI[:,4]) - (Total_Un[:,3] + Total_Un[:,4])
np.mean(deltaei[12:18])
# Out:
# 0.67559206485748291

# %%
residual_ei = (Total_EI[:,2]/Total_Un[:,2])*100

# %%
np.mean(residual_ei[12:18])
# Out:
# 28.971681521118725

# %%
Total_Un[:,2]
# Out:
# array([ 157.89026101,  160.61975584,  153.48109911,  154.81082814,
#         147.32224704,  145.29262828,  155.6506685 ,  153.41110331,
#         150.12171035,  154.04098358,  146.55240248,  127.37601115,
#         150.40166625,  136.54427297,  135.98437485,  136.05438431,
#         112.5388064 ,  106.10001892])

# %%
Total_ZV[:,2]
# Out:
# array([ 54.65970462,  54.02982435,  47.7310114 ,  57.45917135,
#         49.69063777,  50.88041617,  41.99208633,  42.83193352,
#         37.86286667,  66.69743581,  76.84552277,  58.08905845,
#         50.60046711,  46.89116763,  40.80231477,  37.58292103,
#         47.73100799,  51.09037626])

# %%
def CRAWLAB_fft(data, time, plotflag):
    ''' Function to get the FFT for a response
    #
    # Inputs:
    #   time = time array corresponding to the data
    #   data = the response data array (only pass a single dimension/state at at time)
    #   plotflag = will plot the FFT if nonzero
    #   
    # Output:
    #   fft_freq = an array of the freqs used in the FFT
    #   fft_mag = an array of the amplitude of the FFT at each freq in fft_freq
    #
    # Created: 03/28/14
    #   - Joshua Vaughan
    #   - joshua.vaughan@louisiana.edu
    #   - http://www.ucs.louisiana.edu/~jev9637
    #
    # Modified:
    #   * 03/17/16 - JEV - joshua.vaughan@louisiana.edu
    #       - updated for Python 3
    ######################################################################################
    '''
    
    from scipy.fftpack import fft
    
    # correct for any DC offset
    offset = np.mean(data) 

    # Get the sampling time
    sample_time = time[1] - time[0]
    
    # Get the length of the dataset
    n = len(data)

    # Calculate the FFT of the data, removing the offset and using a Hanning Window
    fft_mag = fft((data - offset) * np.hanning(len(data)))
    
    # Define the frequency range of the output
    fft_freq = np.linspace(0.0, 1.0 / (2.0*sample_time), int(np.ceil(n/2)))
    
    # Only return the "useful" part of the fft
    fft_mag = 2.0/n * np.abs(fft_mag[0:int(np.ceil(n/2))])
    
    # If plotflag is nonzero (True), plot the FFT before returning the magnitude and phase
    if plotflag:
        # Plot the relationshiop
        #   Many of these setting could also be made default by the .matplotlibrc file
        fig = plt.figure(figsize=(6,4))
        ax = plt.gca()
        plt.subplots_adjust(bottom=0.17,left=0.17,top=0.96,right=0.96)
        plt.setp(ax.get_ymajorticklabels(),fontsize=18)
        plt.setp(ax.get_xmajorticklabels(),fontsize=18)
        ax.spines['right'].set_color('none')
        ax.spines['top'].set_color('none')
        ax.xaxis.set_ticks_position('bottom')
        ax.yaxis.set_ticks_position('left')
        ax.grid(True, linestyle=':', color='0.75')
        ax.set_axisbelow(True)

        plt.xlabel('Frequency (Hz)', fontsize=22, labelpad=8)
        plt.ylabel('FFT magnitude', fontsize=22, labelpad=10)
    
        plt.plot(fft_freq, fft_mag, linewidth=2, linestyle='-')
        
        # Adjust the page layout filling the page using the new tight_layout command
        plt.tight_layout(pad=0.5)
        plt.show()
    
    return fft_freq, fft_mag
# ------------------------------------------------------------------
# We can also use the FFT to get the natrual frequency
whatever = np.where(box1_command>0)[0][0]
freq, mag = CRAWLAB_fft(pitch[whatever:],time[whatever:],False)

# Let's plot the FFT manually so that we can scale the axes to our liking

# Plot the relationshiop
#   Many of these setting could also be made default by the .matplotlibrc file
fig = plt.figure(figsize=(6,4))
ax = plt.gca()
plt.subplots_adjust(bottom=0.17,left=0.17,top=0.96,right=0.96)
plt.setp(ax.get_ymajorticklabels(),fontsize=18)
plt.setp(ax.get_xmajorticklabels(),fontsize=18)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.grid(True,linestyle=':',color='0.75')
ax.set_axisbelow(True)

plt.xlabel('Frequency (Hz)',fontsize=22,labelpad=8)
plt.ylabel('FFT magnitude',fontsize=22,labelpad=10)

plt.plot(freq, mag, linewidth=2, linestyle='-', label = 'FFT')

# Plto and output the location of the highest peak - The fundamental frequency
freq_index = np.argmax(mag)
print('\nThe highest magnitude peak occurs at {:.4f} Hz.\n'.format(freq[freq_index]))

plt.plot([freq[freq_index], freq[freq_index]], [0, 1.1 * np.max(mag)], 
         linewidth = 2, linestyle = '-.', label = r'$\omega_n \approx$ {:.2f}Hz'.format(freq[freq_index]))

plt.xlim(0,5)

# Create the legend, then fix the fontsize
leg = plt.legend(loc='upper right', ncol = 1, fancybox=True)
ltext  = leg.get_texts()
plt.setp(ltext, family='serif', fontsize=20)

# Adjust the page layout filling the page using the new tight_layout command
plt.tight_layout(pad=0.5)


# save the figure as a high-res pdf in the current folder
# plt.savefig('FFT_magnitude.pdf', dpi=600)

fig.set_size_inches(9,6) # Resize the figure for better display in the notebook
# Out:
# The highest magnitude peak occurs at 0.9394 Hz.

# %%
FFT_of_unshaped = np.array([[9727,9552,9530,9299,9574,9557,9437,9293,9152,9537,9667,9404,
           9397,9512,9393,9491,9394]])
final = FFT_of_unshaped/10000
np.mean(final)
# Out:
# 0.94656470588235297
