# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

high = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/nat_freq_high.npy')
low = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/nat_freq_low.npy')
middle = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/nat_freq_middle.npy')
middle2 = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/nat_freq_middle2.npy')
middle3 = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/nat_freq_middle3.npy')

highd = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/damping_high.npy')
lowd = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/damping_low.npy')
middled = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/damping_middle.npy')
middle2d = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/damping_middle2.npy')
middle3d = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/damping_middle3.npy')

# high = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/nat_freq_high_5.28.npy')
# low = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/nat_freq_low_5.28.npy')
# middle = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/nat_freq_middle_5.28.npy')
# middle2 = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/nat_freq_middle2_5.28.npy')
# middle3 = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/nat_freq_middle3_5.28.npy')

# highd = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/damping_high_5.28.npy')
# lowd = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/damping_low_5.28.npy')
# middled = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/damping_middle_5.28.npy')
# middle2d = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/damping_middle2_5.28.npy')
# middle3d = np.load('/Users/forrest/Desktop/Nat_freq_and_damping/damping_middle3_5.28.npy')

# %%
stats = (low_to_2/(2*np.pi))
mean = round(np.mean(stats), 3)
median = round(np.median(stats), 3)
npmin = round(np.min(stats), 3)
npmax = round(np.max(stats), 3)
percent = round((np.abs(npmax-npmin) / (0.5*(npmax+npmin)))*100, 3)
std = round(np.std(stats), 3)
print('& {} & {} & {} & {} & {} & {}'.format(mean, median,npmin,npmax,percent,std))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e93009d47a7e> in <module>()
# ----> 1 stats = (low_to_2/(2*np.pi))
#       2 mean = round(np.mean(stats), 3)
#       3 median = round(np.median(stats), 3)
#       4 npmin = round(np.min(stats), 3)
#       5 npmax = round(np.max(stats), 3)
#
# NameError: name 'low_to_2' is not defined

# %%
x_values = np.linspace(1,9.4,100)
# x_values = np.linspace(1,5,100)
z_values = np.linspace(0.5,3,100)


# high = high.reshape(100,100)
# low_to_3 = low.reshape(100,100)
# middle = middle.reshape(100,100)
# middle2 = middle2.reshape(100,100)
# middle3 = middle3.reshape(100,100)

# highd = highd.reshape(100,100)
# lowd = lowd.reshape(100,100)
# middled = middled.reshape(100,100)
# middle2d = middle2d.reshape(100,100)
# middle3d = middle3d.reshape(100,100)

# %%
z_values = np.linspace(0.5,2,60)
low_to_2 = low[:6000].reshape(60,100)
middle_to_2 = middle[:6000].reshape(60,100)
middle2_to_2 = middle2[:6000].reshape(60,100)
middle3_to_2 = middle3[:6000].reshape(60,100)
high_to_2 = high[:6000].reshape(60,100)

highd_to_2 = highd[:6000].reshape(60,100)
lowd_to_2 = lowd[:6000].reshape(60,100)
middled_to_2 = middled[:6000].reshape(60,100)
middle2d_to_2 = middle2d[:6000].reshape(60,100)
middle3d_to_2 = middle3d[:6000].reshape(60,100)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
jimmy = np.reshape(low[:6000],(6000,1))
jimmy_r = np.reshape(low5[:6000],(6000,1))
data = np.hstack([jimmy/(2*np.pi), jimmy_r/(2*np.pi)])
df = pd.DataFrame(data, columns=["x", "y"])
sns.jointplot(x="x", y="y", data=df, kind="hex");
# Out:
# //anaconda/lib/python3.5/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f4a6af76a933> in <module>()
#       3 import seaborn as sns
#       4 jimmy = np.reshape(low[:6000],(6000,1))
# ----> 5 jimmy_r = np.reshape(low5[:6000],(6000,1))
#       6 data = np.hstack([jimmy/(2*np.pi), jimmy_r/(2*np.pi)])
#       7 df = pd.DataFrame(data, columns=["x", "y"])
#
# NameError: name 'low5' is not defined

# %%
np.save('/Users/forrest/Desktop/jimmy',jimmy)
np.save('/Users/forrest/Desktop/jimmy5',jimmy_r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8a8728ba74c9> in <module>()
#       1 np.save('/Users/forrest/Desktop/jimmy',jimmy)
# ----> 2 np.save('/Users/forrest/Desktop/jimmy5',jimmy_r)
#
# NameError: name 'jimmy_r' is not defined

# %%
# title = 'Angle Over Workspace'
fig, ax = plt.subplots()
x = x_values
z = z_values
X,Z = np.meshgrid(x,z)

# fig, ax1 = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))
# ax = fig.add_subplot(111)
# ax.spines['top'].set_color('none')
# ax.spines['bottom'].set_color('none')
# ax.spines['left'].set_color('none')
# ax.spines['right'].set_color('none')
# ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')
# ax.set_xlabel('common xlabel')
# ax.set_ylabel('common ylabel')
# fig.subplots_adjust(wspace=0.5, hspace=0.3)
# fig.text(0.54, 0.0001, 'Horizontal Motion', ha='center', size=24)
# fig.text(0.04, 0.5, 'Vertical Motion', va='center', rotation='vertical', size=24)


# plt.pcolormesh(X,Z,low_to_2/(2*np.pi), cmap=plt.cm.bwr)
# plt.ylim(2,0.5)
# plt.xlim(1,9.4)
# cbar = plt.colorbar()
# cbar.ax.set_title('Hz')
# plt.ylabel('Vertical Motion')
# plt.xlabel('Horizontal Motion')
# fig.tight_layout()
# plt.savefig('/Users/forrest/Desktop/freq_low.pdf')


# plt.pcolormesh(X,Z,middle_to_2/(2*np.pi), cmap=plt.cm.bwr)
# plt.ylim(2,0.5)
# plt.xlim(1,9.4)
# cbar = plt.colorbar()
# cbar.ax.set_title('Hz')
# plt.ylabel('Vertical Motion')
# plt.xlabel('Horizontal Motion')
# fig.tight_layout()
# plt.savefig('/Users/forrest/Desktop/freq_middle.pdf')


# plt.pcolormesh(X,Z,middle2_to_2/(2*np.pi), cmap=plt.cm.bwr)
# plt.ylim(2,0.5)
# plt.xlim(1,9.4)
# cbar = plt.colorbar()
# cbar.ax.set_title('Hz')
# plt.ylabel('Vertical Motion')
# plt.xlabel('Horizontal Motion')
# fig.tight_layout()
# plt.savefig('/Users/forrest/Desktop/freq_middle2.pdf')
import matplotlib.ticker as ticker
def fmt(x, pos):
#     a, b = '{:.3e}'.format(x).split('e')
    a = round(x,5)
#     b = int(b)
    return r'${}$'.format(a)

# jimmy = low_to_2
# jimmy = middle_to_2
# jimmy = middle2_to_2
# jimmy = middle3_to_2
jimmy = high_to_2
# jimmy = highd_to_2
# jimmy = lowd_to_2
# jimmy = middled_to_2
# jimmy = middle2d_to_2
# jimmy = middle3d_to_2


plt.pcolormesh(X,Z,jimmy/(2*np.pi), cmap=plt.cm.bwr)
# plt.pcolormesh(X,Z,jimmy, cmap=plt.cm.bwr)
plt.ylim(2,0.5)
plt.xlim(1,9.4)
# plt.xlim(1,5)
cbar = plt.colorbar(format=ticker.FuncFormatter(fmt))
# cbar = plt.colorbar()
cbar.ax.set_title('Hz')
plt.ylabel('Vertical Position (m)')
plt.xlabel('Horizontal Position (m)')
# plt.axis('equal')
# fig.tight_layout()
# plt.savefig('/Users/forrest/Desktop/middle3d.pdf')
# plt.savefig('/Users/Fore/Desktop/lowd.pdf')
# fig.text(0.54, 0.0001, 'Horizontal Motion', ha='center', size=24)
# fig.text(0.01, 0.5, 'Vertical Motion', va='center', rotation='vertical', size=24)
plt.savefig('/Users/forrest/Desktop/high.pdf')

# %%
# title = 'Angle Over Workspace'
# fig, ax = plt.subplots()
x = x_values
z = z_values
X,Z = np.meshgrid(x,z)

fig, ax1 = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))
# ax = fig.add_subplot(111)
# ax.spines['top'].set_color('none')
# ax.spines['bottom'].set_color('none')
# ax.spines['left'].set_color('none')
# ax.spines['right'].set_color('none')
# ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')
# ax.set_xlabel('common xlabel')
# ax.set_ylabel('common ylabel')
# fig.subplots_adjust(wspace=0.5, hspace=0.3)
# fig.text(0.54, 0.0001, 'Horizontal Motion', ha='center', size=24)
# fig.text(0.04, 0.5, 'Vertical Motion', va='center', rotation='vertical', size=24)

plt.subplot(2, 2, 1)
plt.pcolormesh(X,Z,lowd_to_2, cmap=plt.cm.bwr)
plt.ylim(2,0.5)
plt.xlim(1,9.4)
cbar = plt.colorbar()
cbar.ax.set_title('Hz')
plt.ylabel('Vertical Motion')
plt.xlabel('(a)')

plt.subplot(2, 2, 2)
plt.pcolormesh(X,Z,middled_to_2, cmap=plt.cm.bwr)
plt.ylim(2,0.5)
plt.xlim(1,9.4)
cbar = plt.colorbar()
cbar.ax.set_title('Hz')
plt.xlabel('(b)')

plt.subplot(2, 2, 3)
plt.pcolormesh(X,Z,middle2d_to_2, cmap=plt.cm.bwr)
plt.ylim(2,0.5)
plt.xlim(1,9.4)
cbar = plt.colorbar()
cbar.ax.set_title('Hz')
plt.ylabel('Vertical Motion')
plt.xlabel('(c)\nHorizontal Motion')

plt.subplot(2, 2, 4)
plt.pcolormesh(X,Z,middle3d_to_2, cmap=plt.cm.bwr)
plt.ylim(2,0.5)
plt.xlim(1,9.4)
cbar = plt.colorbar()
cbar.ax.set_title('Hz')
plt.xlabel('(d)\nHorizontal Motion')
# plt.savefig('/Users/Fore/Desktop/middle3d.pdf')
# fig.text(0.54, 0.0001, 'Horizontal Motion', ha='center', size=24)
# fig.text(0.01, 0.5, 'Vertical Motion', va='center', rotation='vertical', size=24)
fig.tight_layout()
# plt.savefig('/Users/forrest/Desktop/freq.pdf')

# %%
resp = np.loadtxt('/Users/forrest/Desktop/XY_L1L2_natflmh_damplmh.csv',delimiter=',')
low = resp[:,4]
low = low.reshape(100,100)
fig, ax = plt.subplots()
x_values = np.linspace(1,14,100)
# x_values = np.linspace(1,5,100)
z_values = np.linspace(1,19,100)
x = x_values
z = z_values
X,Z = np.meshgrid(x,z)

plt.pcolormesh(Z,X,low/(2*np.pi), cmap=plt.cm.bwr)
# plt.pcolormesh(X,Z,jimmy, cmap=plt.cm.bwr)
plt.ylim(14,1)
plt.xlim(1,19)
# plt.xlim(1,5)
# cbar = plt.colorbar(format=ticker.FuncFormatter(fmt))
cbar = plt.colorbar()
cbar.ax.set_title('Hz')
plt.ylabel('Vertical Position (m)')
plt.xlabel('Horizontal Position (m)')

# %%
# Out:
# (10000,)
